# %% [markdown]
# <a href="https://colab.research.google.com/github/TVHM/summer_microcredentials_BUS/blob/main/mcd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd

# %%
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
ticker = 'MCD'

# %%
mcd = yf.Ticker(ticker)

# %%
mcd = yf.Ticker(ticker)

# %%
a = mcd.get_earnings()
print(a)
b = mcd.get_shares
print(b)
# Out:
#           Revenue    Earnings
# Year
# 2018  21257900000  5924300000
# 2019  21364400000  6025400000
# 2020  19207800000  4730500000
# 2021  23222900000  7545200000
# <bound method TickerBase.get_shares of yfinance.Ticker object <MCD>>

# %%
mcd.get_balancesheet()
# Out:
#                                                 2021-12-31    2020-12-31  \
# Intangible Assets                             7.950000e+08  6.912000e+08
# Capital Surplus                               8.231600e+09  7.903600e+09
# Total Liab                                    5.845530e+10  6.045170e+10
# Total Stockholder Equity                     -4.601000e+09 -7.824900e+09
# Other Current Liab                            3.640000e+08  8.236000e+08
# Total Assets                                  5.385430e+10  5.262680e+10
# Common Stock                                  1.660000e+07  1.660000e+07
# Other Current Assets                          5.240000e+07  1.856000e+08
# Retained Earnings                             5.753470e+10  5.390810e+10
# Other Liab                                    5.787600e+09  5.752400e+09
# Good Will                                     2.782500e+09  2.773100e+09
# Gains Losses Not Affecting Retained Earnings -7.038390e+10 -6.965320e+10
# ...

# %%
mcd.get_financials()
# Out:
#                                            2021-12-31     2020-12-31  \
# Research Development                             None           None
# Effect Of Accounting Charges                     None           None
# Income Before Tax                        9127900000.0   6140700000.0
# Minority Interest                                None           None
# Net Income                               7545200000.0   4730500000.0
# Selling General Administrative           2377800000.0   2245000000.0
# Gross Profit                            12580200000.0   9752100000.0
# Ebit                                     9873100000.0   7213300000.0
# Operating Income                         9873100000.0   7213300000.0
# Other Operating Expenses                    -400000.0     -6800000.0
# Interest Expense                        -1185800000.0  -1218100000.0
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# ...

# %%
mcd.get_cashflow()
# Out:
#                                              2021-12-31    2020-12-31  \
# Change To Liabilities                      2.250000e+08 -1.375000e+08
# Total Cashflows From Investing Activities -2.165700e+09 -1.545800e+09
# Net Borrowings                            -1.070500e+09  2.238200e+09
# Total Cash From Financing Activities      -5.595600e+09 -2.249000e+09
# Change To Operating Activities             2.840000e+08  4.440000e+07
# Issuance Of Stock                          2.857000e+08  2.955000e+08
# Net Income                                 7.545200e+09  4.730500e+09
# Change In Cash                             1.260100e+09  2.550600e+09
# Repurchase Of Stock                       -8.455000e+08 -9.078000e+08
# Effect Of Exchange Rate                   -1.201000e+08  8.020000e+07
# Total Cash From Operating Activities       9.141500e+09  6.265200e+09
# Depreciation                               1.868100e+09  1.751400e+09
# ...

# %%
mcd.get_analysis()
# Out:
#         Max Age   End Date   Growth  Earnings Estimate Avg  \
# Period
# 0Q            1 2022-09-30 -0.06200                   2.59
# +1Q           1 2022-12-31  0.07600                   2.40
# 0Y            1 2022-12-31  0.05800                   9.82
# +1Y           1 2023-12-31  0.07000                  10.51
# +5Y           1        NaT  0.07230                    NaN
# -5Y           1        NaT  0.05613                    NaN
#
#         Earnings Estimate Low  Earnings Estimate High  \
# Period
# 0Q                       2.49                    2.72
# +1Q                      2.22                    2.60
# 0Y                       9.58                   10.50
# +1Y                      9.85                   11.58
# +5Y                       NaN                     NaN
# -5Y                       NaN                     NaN
#
#         Earnings Estimate Year Ago Eps  Earnings Estimate Number Of Analysts  \
# Period
# ...

# %%
#define a data frame and name the object
mcd = mcd.history(period='max')

# %%
mcd.tail()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2022-10-10 00:00:00-04:00  233.410004  236.259995  233.410004  234.949997
# 2022-10-11 00:00:00-04:00  234.160004  239.119995  233.929993  237.050003
# 2022-10-12 00:00:00-04:00  237.270004  240.039993  237.059998  237.059998
# 2022-10-13 00:00:00-04:00  234.460007  249.300003  234.460007  246.750000
# 2022-10-14 00:00:00-04:00  249.080002  249.429993  242.410004  243.160004
#
#                             Volume  Dividends  Stock Splits
# Date
# 2022-10-10 00:00:00-04:00  2668700        0.0           0.0
# 2022-10-11 00:00:00-04:00  3169200        0.0           0.0
# 2022-10-12 00:00:00-04:00  2709300        0.0           0.0
# 2022-10-13 00:00:00-04:00  5026900        0.0           0.0
# 2022-10-14 00:00:00-04:00  2918300        0.0           0.0

# %%
mcd.head()
# Out:
#                            Open      High       Low     Close   Volume  \
# Date
# 1966-07-05 00:00:00-04:00   0.0  0.123300  0.120519  0.121445   388800
# 1966-07-06 00:00:00-04:00   0.0  0.127935  0.120519  0.127935   692550
# 1966-07-07 00:00:00-04:00   0.0  0.131180  0.122373  0.123300  1858950
# 1966-07-08 00:00:00-04:00   0.0  0.124690  0.120519  0.124690  1239300
# 1966-07-11 00:00:00-04:00   0.0  0.127935  0.122836  0.124227   656100
#
#                            Dividends  Stock Splits
# Date
# 1966-07-05 00:00:00-04:00        0.0           0.0
# 1966-07-06 00:00:00-04:00        0.0           0.0
# 1966-07-07 00:00:00-04:00        0.0           0.0
# 1966-07-08 00:00:00-04:00        0.0           0.0
# 1966-07-11 00:00:00-04:00        0.0           0.0

# %%
mcd.get_institutional_holders()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-125acf29a554> in <module>
# ----> 1 mcd.get_institutional_holders()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'get_institutional_holders'

# %%
mcd.get_major_holders()

# %%
import plotly.express as px

# %%
fig = px.line(mcd,x= mcd.index, y= 'Close', title = 'Interactive Graph for '+ticker)
fig.show()
