# %% [markdown]
# <a href="https://colab.research.google.com/github/TVHM/summer_microcredentials_BUS/blob/main/California_test_score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import dependencies
import pandas as pd
import numpy as np
import statsmodels.api as sm 
import statsmodels.formula.api as smf
 
from scipy.stats import t
from sklearn import linear_model 
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# !pip install linear models
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached linear-0.0.dev0.tar.gz (1.4 kB)
# ...
#   Using cached models-0.9.3.tar.gz (16 kB)
# WARNING: Discarding https://files.pythonhosted.org/packages/92/3c/ac1ddde60c02b5a46993bd3c6f4c66a9dbc100059da8333178ce17a22db5/models-0.9.3.tar.gz#sha256=b5aa29c6b57a667cda667dd9fbd33bbd15c14cc285e57dda64f4f4c0fd35e0ae (from https://pypi.org/simple/models/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached models-0.9.2.tar.gz (16 kB)
# WARNING: Discarding https://files.pythonhosted.org/packages/44/3a/8cd3c08995d89e87e74a9aa04784dcb9ade25c03250c281376ce4942d7f5/models-0.9.2.tar.gz#sha256=308be4d5cb707c63f967c591111a8675fe3eaa59c04516e5f6c7fff5e026ece0 (from https://pypi.org/simple/models/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ...

# %%
california_test_score  = pd.read_csv('/content/Table1.csv')

# %%
data = california_test_score

# %%
#find missing values
data.isnull().sum()
# Out:
# Number       0
# TestScore    0
# STR          0
# EXPN         0
# PCTEL        0
# dtype: int64

# %%
data.head()
# Out:
#    Number  TestScore    STR  EXPN  PCTEL
# 0       1      690.8  17.89  6385    0.0
# 1       2      661.2  21.52  5099    4.6
# 2       3      643.6  18.70  5502   30.0
# 3       4      647.7  17.36  7102    0.0
# 4       5      640.8  18.67  5236   13.9

# %%
#statistica data for variabe STR

# %%
data.shape
# Out:
# (420, 5)

# %%
#STR student teacher ratio, expn expenditure per pupil, pcte perentageof student learning
data.describe()
# Out:
#            Number   TestScore         STR         EXPN       PCTEL
# count  420.000000  420.000000  420.000000   420.000000  420.000000
# mean   210.500000  654.160238   19.640500  5312.385714   15.770476
# std    121.387808   19.052837    1.891858   633.929254   18.284528
# min      1.000000  605.600000   14.000000  3926.000000    0.000000
# 25%    105.750000  640.050000   18.580000  4906.000000    1.900000
# 50%    210.500000  654.450000   19.725000  5214.500000    8.800000
# 75%    315.250000  666.700000   20.870000  5601.750000   22.950000
# max    420.000000  706.800000   25.800000  7712.000000   85.500000

# %%
#test score, EXPN and PCTEL  by STR_median
#STR, EXPN PCTEL by TestScore 
data.groupby('STR').median()
# Out:
#        Number  TestScore    EXPN  PCTEL
# STR
# 14.00    80.0      635.6  6653.0    0.0
# 14.20   229.0      656.5  5636.0    0.0
# 14.54   409.0      695.3  7712.0    3.8
# 14.71   316.0      666.8  6870.0    2.5
# 15.14   412.0      698.3  7593.0    2.8
# ...       ...        ...     ...    ...
# 24.89   324.0      668.1  4743.0    4.5
# 24.95    90.0      637.0  4079.0    5.0
# 25.05    24.0      622.1  4660.0   39.1
# 25.79   210.0      654.2  3926.0    9.6
# 25.80   297.0      664.9  4016.0    6.2
#
# [312 rows x 4 columns]

# %%
data.groupby('TestScore').median()
# Out:
#            Number    STR    EXPN  PCTEL
# TestScore
# 605.6         6.0  21.41  5580.0   12.4
# 606.8         7.0  19.50  5253.0   68.7
# 609.0         8.0  20.89  4566.0   47.0
# 612.5         9.0  19.95  5356.0   30.1
# 612.7        10.0  20.81  5036.0   40.3
# ...           ...    ...     ...    ...
# 698.4       413.0  17.84  6500.0    1.4
# 699.1       414.0  15.41  7217.0    1.2
# 700.3       415.0  18.87  5393.0    2.1
# 704.3       416.0  16.47  7290.0    6.0
# 706.8       417.0  17.86  5741.0    4.7
#
# [323 rows x 4 columns]

# %%
#drop coumn STR X axis , assign STR Y axis 
X = data.drop(columns = 'TestScore', axis=1)
Y = data['STR']

# %%
print(X)
# Out:
#      Number    STR  EXPN  PCTEL
# 0         1  17.89  6385    0.0
# 1         2  21.52  5099    4.6
# 2         3  18.70  5502   30.0
# 3         4  17.36  7102    0.0
# 4         5  18.67  5236   13.9
# ..      ...    ...   ...    ...
# 415     416  16.47  7290    6.0
# 416     417  17.86  5741    4.7
# 417     418  21.89  4403   24.3
# 418     419  20.20  4776    3.0
# 419     420  19.04  5993    5.0
#
# [420 rows x 4 columns]

# %%
print(Y)
# Out:
# 0      17.89
# 1      21.52
# 2      18.70
# 3      17.36
# 4      18.67
#        ...
# 415    16.47
# 416    17.86
# 417    21.89
# 418    20.20
# 419    19.04
# Name: STR, Length: 420, dtype: float64

# %%
reg1 = sm.OLS(endog=data['STR'], exog=data[['EXPN', 'PCTEL']])
results1 = reg1.fit()
print(results1.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                    STR   R-squared (uncentered):                   0.965
# Model:                            OLS   Adj. R-squared (uncentered):              0.965
# Method:                 Least Squares   F-statistic:                              5767.
# Date:                Sun, 28 Aug 2022   Prob (F-statistic):                   4.40e-305
# Time:                        02:10:37   Log-Likelihood:                         -1144.3
# No. Observations:                 420   AIC:                                      2293.
# Df Residuals:                     418   BIC:                                      2301.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
statistics(fractiles).STR
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-260-04c71ff11232> in <module>
# ----> 1 statistics(fractiles).STR
#
# NameError: name 'statistics' is not defined

# %%
#STR rate by EXPN and PCTEL
#data.pivot_table('STR', index='EXPN', columns='PCTEL').plot()

# %%
#plot the 
sns.barplot(x='Number', y='STR', data=california_test_score )

# %%
from matplotlib import figure
#Visualize the count of survivors for the columns sets: 'who', 'sex', 'pclass','sibsp', 'parch', 'embarked'
#different values for each column example sex : 2 values - male or female , parch meaning parent or child etc. 
cols = ['who', 'sex', 'pclass','sibsp', 'parch', 'embarked']

#make plots for column names 
n_rows = 2
n_cols = 3

#create the subplot grid fugure size of each graph 
fig, axs = plt.subplots(n_rows, n_cols, figsize = (n_cols * 3.2, n_rows * 3.2) )

for r in range(0, n_rows):
  for c in range(0, n_cols):

    i = r*n_cols + c  #index to go through the number of columns
    ax = axs[r][c]    #show where to position each sub plot
    sns.countplot(titanic[cols[i]], hue=titanic['survived'], ax=ax) 
    #i is for the loop to pass through each column
    ax.set_title(cols[i])
    ax.legend(title='survived', loc = 'upper right')
    plt.tight_layout()

# %%
#initialize the linear regression model
reg = linear_model.LinearRegression()
